# %%
# install wget for Google Colab
# !pip install wget

# %%
import requests
import wget
import os
from bs4 import BeautifulSoup, SoupStrainer

# %%
#  connects Colab to Google Drive
from google.colab import drive
drive.mount('/content/drive/')

# folder where files will be downloaded
destination_path = '/content/drive/MyDrive/Python/Datasets'
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# url with datasets
url_base = 'https://www.contextures.com/' 
url_endpoint = 'xlsampledata01.html'
response = requests.get(url_base + url_endpoint)

# valid file types
# file_types = ['.xls', '.xlsx', '.csv']
file_types = ['.zip']
file_counter = 0

# %%
# creates soup with all links with 'a' tag
soup = BeautifulSoup(response.content, 'html.parser', parse_only=SoupStrainer('a'))

# %%
# soup visualization
print(soup)
# Out:
# <a class="navbar-brand" href="https://www.contextures.com/">Home</a><a href="https://www.contextures.com/tiptech.html">Tips</a><a href="https://www.contextures.com/excelfiles.html">Files</a><a href="https://www.contextures.com/contexturesproducts.html">Products</a><a href="https://www.contextures.com/newsletter/ctxnewsindexlist.html">Newsletter</a><a href="https://contexturesblog.com/">Blog</a><a href="https://www.contextures.com/index.html"><img alt="Contextures" class="img-responsive" height="49" src="https://www.contextures.com/contextures.gif" width="314"/></a><a name="Top"></a><a href="#office">Sample Data - Office Supply Sales</a><a href="#data">Sample Data - Office Supply Sales Table</a><a href="#inspol">Sample Data - Insurance Policies</a><a href="#food">Sample Data - Food Sales</a><a href="#safety">Sample Data - Workplace Safety</a><a href="#wos">Sample Data - Work Orders</a><a href="#hockey">Sample Data - Hockey Players</a><a href="#hockeypt">Sample Data - Hockey Player Ana
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# iterates through every data type
for file_type in file_types:
    
    # waits for server response
    if (response.ok):
        print('Connecting to server...')
        
        # iterates through every links in soup
        for link in soup:
            if link.has_attr('href'):
              if file_type in link['href']:
                  full_path = url_base + link['href']
                  print('Path file: ', full_path)
                  wget.download(full_path, out=destination_path)
                  file_counter+=1
        
        # display file counter          
        print(file_counter, file_type, 'files found')
    
    else:
      print('Error: Unable to connect to server')
# Out:
# Connecting to server...
# Path file:  https://www.contextures.com/tablesamples/sampledatasafety.zip
# Path file:  https://www.contextures.com/SampleData.zip
# Path file:  https://www.contextures.com/tablesamples/sampledatainsurance.zip
# Path file:  https://www.contextures.com/tablesamples/sampledatafoodsales.zip
# Path file:  https://www.contextures.com/tablesamples/sampledatasafety.zip
# Path file:  https://www.contextures.com/tablesamples/sampledataworkorders.zip
# Path file:  https://www.contextures.com/tablesamples/sampledatahockey.zip
# Path file:  https://www.contextures.com/pivotsamples/hockeyplayerdata2018.zip
# Path file:  https://www.contextures.com/tablesamples/sampledatawinterathletes.zip
# 9 .zip files found
